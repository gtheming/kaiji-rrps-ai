# %%
import sys, os

sys.path.insert(0, os.path.abspath(".."))
from environment_static.Q_learn import QLearnStatic
from environment_static.rrps_gym import StaticRRPSEnv

env = StaticRRPSEnv(
    n_opponents=1,
    agent_budget={"paper_total": 1, "rock_total": 1, "scissors_total": 1},
    player_budget={"paper_total": 1, "rock_total": 1, "scissors_total": 1},
)
q_learn = QLearnStatic(agent_name="monty_hall", env=env)

agent = q_learn.tabular_train(
    gamma=0.9, train_episodes=20_000, decay_rate=0.999, gui=False
)
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]
# 0
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 14
#      10     player_budget={"paper_total": 1, "rock_total": 1, "scissors_total": 1},
#      11 )
#      12 q_learn = QLearnStatic(agent_name="monty_hall", env=env)
#      13
# ---> 14 agent = q_learn.tabular_train(
#      15     gamma=0.9, train_episodes=20_000, decay_rate=0.999, gui=True
#      16 )
#
# File ~/school/AI/kaiji-rrps-ai/gym_core/Q_learn.py:96, in RRPSQLearnCore.tabular_train(self, train_episodes, gamma, decay_rate, epsilon, gui)
#      93 Q_update_counts[prev_state_key][action] += 1
#      95 if gui:
# ---> 96     self.render_gui(terminated, truncated, info)
#      97 # update epsilon and end or continue w/ new step as prev
#      99 if terminated:
#
# File ~/school/AI/kaiji-rrps-ai/environment_static/Q_learn.py:35, in QLearnStatic.render_gui(self, terminated, truncated, info)
#      33 def render_gui(self, terminated, truncated, info):
#      34     if not vis.is_initialized():
# ---> 35         vis.init()
#      36     vis.refresh(terminated, truncated, info)
#
# File ~/school/AI/kaiji-rrps-ai/gym_core/visualizer.py:65, in init(width, height, grid_rows, grid_cols)
#      62 pygame.display.set_caption("RPS Arena")
#      63 clock = pygame.time.Clock()
# ---> 65 _rebuild_menus()
#
# File ~/school/AI/kaiji-rrps-ai/gym_core/visualizer.py:39, in _rebuild_menus()
#      28 w = _table_width
#      29 theme = pygame_menu.Theme(
#      30     background_color=(20, 24, 34),
#      31     title=False,
#    (...)     37     widget_border_color=(40, 48, 68),
#      38 )
# ---> 39 control_menu = pygame_menu.Menu("", 200, 60, position=(w - 200, 0, False), theme=theme)
#      40 control_menu.add.button(f"autoplay: {'ON' if autoplay else 'OFF'}", _toggle_autoplay_btn)
#      41 next_round_menu = pygame_menu.Menu("", 200, 60, position=(w - 200, 60, False), theme=theme)
#
# File ~/school/AI/kaiji-rrps-ai/.venv/lib/python3.13/site-packages/pygame_menu/menu.py:541, in Menu.__init__(self, title, width, height, center_content, column_max_width, column_min_width, columns, enabled, joystick_enabled, keyboard_enabled, keyboard_ignore_nonphysical, menu_id, mouse_enabled, mouse_motion_selection, mouse_visible, mouse_visible_update, onclose, onreset, overflow, position, remember_selection, rows, screen_dimension, surface, theme, touchscreen, touchscreen_motion_selection, verbose)
#     528 self._menubar._verbose = verbose
#     530 self._menubar.set_font(
#     531     antialias=self._theme.title_font_antialias,
#     532     background_color=None,
#    (...)    538     selected_color=self._theme.title_font_color
#     539 )
# --> 541 self._menubar.set_menu(self)
#     543 self._menubar.set_cursor(self._theme.title_close_button_cursor)
#     544 self._menubar.set_font_shadow(
#     545     color=self._theme.title_font_shadow_color,
#     546     enabled=self._theme.title_font_shadow,
#     547     offset=self._theme.title_font_shadow_offset,
#     548     position=self._theme.title_font_shadow_position
#     549 )
#
# File ~/school/AI/kaiji-rrps-ai/.venv/lib/python3.13/site-packages/pygame_menu/widgets/core/widget.py:1965, in Widget.set_menu(self, menu)
#    1963     self._selected = False
#    1964     self.active = False
# -> 1965 self._force_render()
#    1966 return self
#
# File ~/school/AI/kaiji-rrps-ai/.venv/lib/python3.13/site-packages/pygame_menu/widgets/core/widget.py:824, in Widget._force_render(self)
#     811 """
#     812 Forces Widget render.
#     813
#    (...)    821 :return: Render return value
#     822 """
#     823 self._last_render_hash = 0
# --> 824 return self._render()
#
# File ~/school/AI/kaiji-rrps-ai/.venv/lib/python3.13/site-packages/pygame_menu/widgets/widget/menubar.py:305, in MenuBar._render(self)
#     302 else:
#     303     self._box_mode = _MODE_BACK
# --> 305 self._surface = self._render_string(self._title, self._font_selected_color)
#     306 self._rect.width, self._rect.height = self._surface.get_size()
#     307 self._apply_transforms()  # Rotation does not affect rect size
#
# File ~/school/AI/kaiji-rrps-ai/.venv/lib/python3.13/site-packages/pygame_menu/widgets/core/widget.py:1716, in Widget._render_string(self, string, color)
#    1708 def _render_string(self, string: str, color: ColorInputType) -> 'pygame.Surface':
#    1709     """
#    1710     Render text and turn it into a surface.
#    1711
#    (...)   1714     :return: Text surface
#    1715     """
# -> 1716     text = self._font_render_string(string, color)
#    1718     # Create surface
#    1719     surface = make_surface(
#    1720         width=text.get_width(),
#    1721         height=text.get_height(),
#    1722         alpha=True
#    1723     )
#
# File ~/school/AI/kaiji-rrps-ai/.venv/lib/python3.13/site-packages/pygame_menu/widgets/core/widget.py:1705, in Widget._font_render_string(self, text, color, use_background_color)
#    1703 # Replace tabs
#    1704 text = text.replace('\t', ' ' * self._tab_size)
# -> 1705 surface = self._font.render(text, self._font_antialias, color, bgcolor)
#    1706 return surface
#
# error: Invalid font (font module quit since font created)
