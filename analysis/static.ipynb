# %%
import sys, os
sys.path.insert(0, os.path.abspath(".."))
from environment_static.Q_learn import QLearnStatic
from environment_static.rrps_gym import StaticRRPSEnv
from tqdm import tqdm
# Out:
# /home/russ/school/AI/kaiji-rrps-ai/.venv/lib/python3.13/site-packages/pandera/_pandas_deprecated.py:154: FutureWarning: Importing pandas-specific classes and functions from the
# top-level pandera module will be **removed in a future version of pandera**.
# If you're using pandera to validate pandas objects, we highly recommend updating
# your import:
#
# ```
# # old import
# import pandera as pa
#
# # new import
# import pandera.pandas as pa
# ```
#
# If you're using pandera to validate objects from other compatible libraries
# like pyspark or polars, see the supported libraries section of the documentation
# for more information on how to import pandera:
#
# https://pandera.readthedocs.io/en/stable/supported_libraries.html
#
# To disable this warning, set the environment variable:
#
# ```
# export DISABLE_PANDERA_IMPORT_WARNING=True
# ```
#
#   warnings.warn(_future_warning, FutureWarning)

# %%
sys.path.insert(0, os.path.abspath(".."))
from environment_static.Q_learn import QLearnStatic
from environment_static.rrps_gym import StaticRRPSEnv

env = StaticRRPSEnv(
    n_opponents=1,
    agent_budget={"paper_total": 3, "rock_total": 3, "scissors_total": 3},
    player_budget={"paper_total": 3, "rock_total": 3, "scissors_total": 3},
)
monty_hall = QLearnStatic(agent_name="monty_hall", env=env)

monty_hall.tabular_train(
    gamma=0.9, train_episodes=20_000, decay_rate=0.999, gui=False
)
# Out:
# 100%|██████████| 20000/20000 [06:17<00:00, 52.96it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 12
#       8     player_budget={"paper_total": 3, "rock_total": 3, "scissors_total": 3},
#       9 )
#      10 monty_hall = QLearnStatic(agent_name="monty_hall", env=env)
#      11
# ---> 12 monty_hall.tabular_train(
#      13     gamma=0.9, train_episodes=20_000, decay_rate=0.999, gui=False
#      14 )
#
# File ~/school/AI/kaiji-rrps-ai/gym_core/Q_learn.py:117, in RRPSQLearnCore.tabular_train(self, train_episodes, gamma, decay_rate, epsilon, gui, agent_name)
#     115             prev_state_key = new_state_key
#     116 name = agent_name or self.agent_name
# --> 117 with open(self._file_name(name), "wb") as handle:
#     118     pickle.dump(Q_table, handle, protocol=pickle.HIGHEST_PROTOCOL)
#     119 self.Q_table = Q_table
#
# TypeError: RRPSQLearnCore._file_name() missing 2 required positional arguments: 'train_episodes' and 'decay_rate'

# %%
rewards = []
wins = 0
losses = 0
truncations = 0

for _ in tqdm(range(10_000)):
    total_reward = 0
    for obs, reward, terminated, truncated, info in monty_hall.play_agent():
        total_reward += reward
    rewards.append(total_reward)
    if info["game_status"] == "victory":
        wins += 1
    elif info["game_status"] == "eliminated":
        losses += 1
    else:
        truncations += 1

total = len(rewards)
avg_reward = sum(rewards) / total
print(f"avg_reward: {avg_reward:.2f}")
print(f"win rate:   {wins/total*100:.1f}%  ({wins}/{total})")
print(f"loss rate:  {losses/total*100:.1f}%  ({losses}/{total})")
print(f"truncated:  {truncations/total*100:.1f}%  ({truncations}/{total})")
# Out:
# 100%|██████████| 10000/10000 [01:25<00:00, 116.75it/s]
# avg_reward: 761.21
# win rate:   83.1%  (8313/10000)
# loss rate:  16.9%  (1687/10000)
# truncated:  0.0%  (0/10000)
