# %%
import pandas as pd

# %%
df = pd.read_csv('dynamic_results_1000.csv')
df.head()
# Out:
#    episode game_status  total_reward  turns  agent_stars  agent_cards_left  \
# 0        0     victory        2060.5     63            3                 0
# 1        1  eliminated        -764.0     23            0                 2
# 2        2     victory        2270.0     33            5                 0
# 3        3     victory        2048.0     66            3                 3
# 4        4     victory        2231.5     34            5                 0
#
#    opponents_alive
# 0                2
# 1                2
# 2                1
# 3                0
# 4                1

# %%
df[df["game_status"] == "victory"].shape
# Out:
# (643, 7)
